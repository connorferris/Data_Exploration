# %%
import pandas as pd
import matplotlib.pyplot as plt
import math
import statistics as stats

# %%
datafile = "CCM Computing Literacy Course Entry Survey - Fall 2020.csv"
df = pd.read_csv(datafile)

# %%
pd.set_option('precision', 2)

# %%
df.head()
# Out:
#                     Timestamp  Which course are you currently enrolled in?  \
# 0  2020/07/08 10:30:22 AM EST  CMP 135 Computer Concepts with Applications
# 1  2020/07/08 11:15:08 AM EST  CMP 135 Computer Concepts with Applications
# 2  2020/07/08 11:22:23 AM EST  CMP 135 Computer Concepts with Applications
# 3   2020/07/08 2:14:53 PM EST  CMP 135 Computer Concepts with Applications
# 4   2020/07/08 3:34:11 PM EST  CMP 135 Computer Concepts with Applications
#
#   What motivated you to seek a computing class at CCM?  \
# 0   It’s a required class for the degree I’m seeking
# 1  It’s a required class for the degree I’m seeki...
# 2  To keep current in computing skills;Career Adv...
# 3   It’s a required class for the degree I’m seeking
# 4   It’s a required class for the degree I’m seeking
#
# ...

# %%
df.tail()
# Out:
#                      Timestamp   Which course are you currently enrolled in?  \
# 197  2020/09/27 5:07:35 PM EST   CMP 135 Computer Concepts with Applications
# 198  2020/09/30 8:45:44 AM EST   CMP 135 Computer Concepts with Applications
# 199  2020/09/30 5:35:39 PM EST         CMP 101 Computer Information Literacy
# 200  2020/10/04 6:44:31 PM EST  CMP 126 Computer Technology and Applications
# 201  2020/10/10 3:59:29 PM EST  CMP 126 Computer Technology and Applications
#
#     What motivated you to seek a computing class at CCM?  \
# 197   It’s a required class for the degree I’m seeking
# 198   It’s a required class for the degree I’m seeking
# 199  To keep current in computing skills;Personal E...
# 200   It’s a required class for the degree I’m seeking
# 201  It’s a required class for the degree I’m seeki...
#
# ...

# %%
df.head()
# Out:
#                     Timestamp  Which course are you currently enrolled in?  \
# 0  2020/07/08 10:30:22 AM EST  CMP 135 Computer Concepts with Applications
# 1  2020/07/08 11:15:08 AM EST  CMP 135 Computer Concepts with Applications
# 2  2020/07/08 11:22:23 AM EST  CMP 135 Computer Concepts with Applications
# 3   2020/07/08 2:14:53 PM EST  CMP 135 Computer Concepts with Applications
# 4   2020/07/08 3:34:11 PM EST  CMP 135 Computer Concepts with Applications
#
#   What motivated you to seek a computing class at CCM?  \
# 0   It’s a required class for the degree I’m seeking
# 1  It’s a required class for the degree I’m seeki...
# 2  To keep current in computing skills;Career Adv...
# 3   It’s a required class for the degree I’m seeking
# 4   It’s a required class for the degree I’m seeking
#
# ...

# %%
df.describe()
# Out:
#        On a scale of 1 to 5, with 1 being not at all interested and 5 being extremely interested, how interested are you taking more courses in Computer Science, Information Technology or Game Development?
# count                                             202.00
# mean                                                2.48
# std                                                 1.15
# min                                                 1.00
# 25%                                                 2.00
# 50%                                                 2.00
# 75%                                                 3.00
# max                                                 5.00

# %%
# %matplotlib inline

# %%
histogram = df.hist()

# %% [markdown]
# This showed me the interest levels of students in a plot

# %%
df.columns
# Out:
# Index(['Timestamp', 'Which course are you currently enrolled in?',
#        'What motivated you to seek a computing class at CCM?',
#        'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Open House]',
#        'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Instant Decision Day]',
#        'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [On-Campus Information Session]',
# ...

# %%
df['On a scale of 1 to 5, with 1 being not at all interested and 5 being extremely interested, how interested are you taking more courses in Computer Science, Information Technology or Game Development?'].mean()
# Out:
# 2.48019801980198

# %% [markdown]
# Showed me that students are not very interested in the classes

# %%
interestlevel = df[df['On a scale of 1 to 5, with 1 being not at all interested and 5 being extremely interested, how interested are you taking more courses in Computer Science, Information Technology or Game Development?']>4]

# %%
interestlevel
# Out:
#                       Timestamp   Which course are you currently enrolled in?  \
# 2    2020/07/08 11:22:23 AM EST   CMP 135 Computer Concepts with Applications
# 4     2020/07/08 3:34:11 PM EST   CMP 135 Computer Concepts with Applications
# 6     2020/07/11 9:34:30 PM EST   CMP 135 Computer Concepts with Applications
# 12   2020/09/08 10:00:50 AM EST         CMP 101 Computer Information Literacy
# 65   2020/09/15 11:11:35 AM EST   CMP 135 Computer Concepts with Applications
# 128   2020/09/21 7:41:36 PM EST   CMP 135 Computer Concepts with Applications
# 164   2020/09/23 8:52:53 AM EST   CMP 135 Computer Concepts with Applications
# 169   2020/09/23 1:02:28 PM EST  CMP 126 Computer Technology and Applications
# 179   2020/09/24 6:48:26 PM EST         CMP 101 Computer Information Literacy
# 180   2020/09/24 6:48:43 PM EST         CMP 101 Computer Information Literacy
# 181   2020/09/24 6:49:17 PM EST   CMP 135 Computer Concepts with Applications
# ...

# %%
df['On a scale of 1 to 5, with 1 being not at all interested and 5 being extremely interested, how interested are you taking more courses in Computer Science, Information Technology or Game Development?'].value_counts()
# Out:
# 3    60
# 2    59
# 1    47
# 4    24
# 5    12
# Name: On a scale of 1 to 5, with 1 being not at all interested and 5 being extremely interested, how interested are you taking more courses in Computer Science, Information Technology or Game Development?, dtype: int64

# %% [markdown]
# Here I learned that students are not very intersted in going father into the computing courses.

# %%
df['Gender'].value_counts()
# Out:
# Woman                123
# Man                   73
# Prefer not to say      4
# I do not identify      1
# Name: Gender, dtype: int64

# %%
df['Race/ethnicity'].value_counts()
# Out:
# White/Caucasian                                        127
# Hispanic or Latino                                      30
# Black/African American                                  11
# Choose not to reply                                      9
# Asian                                                    7
# Multi-Racial                                             5
# Hispanic or Latino;White/Caucasian                       5
# Hispanic or Latino;Multi-Racial                          2
# Asian;White/Caucasian                                    2
# Black/African American;White/Caucasian;Multi-Racial      1
# Asian;Multi-Racial                                       1
# White/Caucasian;Multi-Racial                             1
# Hispanic or Latino;Black/African American                1
# Name: Race/ethnicity, dtype: int64

# %%
df['Age '].value_counts()
# Out:
# 19-20             94
# 21-24             49
# 18 and younger    26
# 25-34             22
# 35-64             10
# 65+                1
# Name: Age , dtype: int64

# %% [markdown]
# Showed me the ages of people who took the survey

# %%
df.dtypes
# Out:
# Timestamp                                                                                                                                                                                                                              object
# Which course are you currently enrolled in?                                                                                                                                                                                            object
# What motivated you to seek a computing class at CCM?                                                                                                                                                                                   object
# Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Open House]                         object
# ...

# %%
motivation = df['What motivated you to seek a computing class at CCM?']
motivation
# Out:
# 0       It’s a required class for the degree I’m seeking
# 1      It’s a required class for the degree I’m seeki...
# 2      To keep current in computing skills;Career Adv...
# 3       It’s a required class for the degree I’m seeking
# 4       It’s a required class for the degree I’m seeking
#                              ...
# 197     It’s a required class for the degree I’m seeking
# 198     It’s a required class for the degree I’m seeking
# 199    To keep current in computing skills;Personal E...
# 200     It’s a required class for the degree I’m seeking
# 201    It’s a required class for the degree I’m seeki...
# Name: What motivated you to seek a computing class at CCM?, Length: 202, dtype: object

# %%
motivation.value_counts()
# Out:
# It’s a required class for the degree I’m seeking                                                                                                                                                                                                                                                                                                                                                                   119
# It’s a required class for the degree I’m seeking;To keep current in computing skills                                                                                                                                                                                                                                                                                                                                18
# ...

# %% [markdown]
# From this I learned that students are not taking the class because they are interested/curious. But more because it is required.

# %%
hearabout = df['How did you hear about County College of Morris (check all that apply)?']
hearabout
# Out:
# 0                                Family member or friend
# 1                                            High School
# 2      Web site;Family member or friend;Current stude...
# 3      Web site;Social Media;Community Event;Family m...
# 4                            Current student;High School
#                              ...
# 197                                          High School
# 198                             Social Media;High School
# 199     Family member or friend;Alumni;High School;local
# 200                                          High School
# 201                                           Therapist
# Name: How did you hear about County College of Morris (check all that apply)?, Length: 202, dtype: object

# %%
hearabout.value_counts()
# Out:
# High School                                                                                           30
# Family member or friend                                                                               22
# Family member or friend;High School                                                                   18
# Family member or friend;Current student;High School                                                   11
# Family member or friend;Current student;Alumni;High School                                            10
#                                                                                                       ..
# Web site;Social Media;Community Event;Family member or friend;Employer;Current student;High School     1
# Web site;Family member or friend;Current student;High School;Live nearby                               1
# Web site;Social Media;Family member or friend;High School                                              1
# ...

# %% [markdown]
# As I expected with CCM being a community college most people here about it through a local high school or family.  Unlike a big school social media and website dont play a big role

# %%
reasons = df[['To what extent did the following impact your decision to attend County College of Morris? [Affordable cost]','To what extent did the following impact your decision to attend County College of Morris? [Location/convenience]','To what extent did the following impact your decision to attend County College of Morris? [Choice of programs]','To what extent did the following impact your decision to attend County College of Morris? [Online offerings]','To what extent did the following impact your decision to attend County College of Morris? [Family/friend referral]','To what extent did the following impact your decision to attend County College of Morris? [Faculty/staff]','To what extent did the following impact your decision to attend County College of Morris? [College reputation]','To what extent did the following impact your decision to attend County College of Morris? [Scholarships]','To what extent did the following impact your decision to attend County College of Morris? [Transfer student]','To what extent did the following impact your decision to attend County College of Morris? [Small class sizes]','To what extent did the following impact your decision to attend County College of Morris? [Extra curricula opportunities]']]
reasons
# Out:
#     To what extent did the following impact your decision to attend County College of Morris? [Affordable cost]  \
# 0                                          High Impact
# 1                                            No Impact
# 2                                          Some Impact
# 3                                          High Impact
# 4                                          Some Impact
# ..                                                 ...
# 197                                        High Impact
# 198                                        Some Impact
# 199                                        High Impact
# 200                                                NaN
# 201                                        Some Impact
#
#     To what extent did the following impact your decision to attend County College of Morris? [Location/convenience]  \
# 0                                          High Impact
# 1                                          High Impact
# ...

# %% [markdown]
# As expected students chose CCM due to location, cost, and family members. Not suprising being it is a county college. The size of the classes dont seem to matter.
